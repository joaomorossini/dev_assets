# %%
import os
import yaml
from langchain.agents import create_tool_calling_agent, AgentExecutor
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from composio_langchain import ComposioToolSet, App, Action
from langchain.memory import ConversationBufferMemory
from langchain.tools import StructuredTool
from langchain_core.tools import ToolException
from typing import List, Optional, Dict, Any
from pydantic import ValidationError
from pprint import pprint
from datetime import datetime
import warnings

warnings.filterwarnings("ignore")
# Out:
# /Users/morossini/anaconda3/envs/composio/lib/python3.12/site-packages/paramiko/pkey.py:100: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# /Users/morossini/anaconda3/envs/composio/lib/python3.12/site-packages/paramiko/transport.py:259: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,

# %%
def test_composio_clickup_tools(actions_with_args: List[Dict[str, Any]]):
    start_time = datetime.now()
    composio_toolset = ComposioToolSet()
    short_results = []
    full_results = []

    for action in actions_with_args:
        try:
            clickup_action = composio_toolset.get_actions(actions=[getattr(Action, action["name"])])
            result = clickup_action[0].invoke(action["args"])
            short_results.append({"action": action["name"], "executed": result['execution_details']})
            full_results.append({"action": action["name"], "results": result})
        except Exception as e:
            short_results.append({"action": action["name"], "executed": result['execution_details']})
            full_results.append({"action": action["name"], "executed": result['execution_details'], "error": str(e)})
        print(short_results[-1])
    end_time = datetime.now()
    print(f"Total time taken: {end_time - start_time}")
    return short_results, full_results

# %% [markdown]
# # TEST 1
# Using VALID task ids

# %%
team_id = 12927880
list_id = 901304862476
task_name = "-_-_NOVO TESTE COMPOSIO CLICKUP_-_-"
task_id = "86a4crwd0"
task_id_2 = "86a4crwh1"
folder_id = "54804921"
updated_task_name = "NEW UPDATED TASK NAME"

actions_with_args_1 = [
    {
        "name": "CLICKUP_AUTHORIZATION_VIEW_ACCOUNT_DETAILS",
        "args": {}
    },
    {
        "name": "CLICKUP_AUTHORIZATION_GET_WORK_SPACE_LIST",
        "args": {}
    },
    {
        "name": "CLICKUP_CREATE_TASK",
        "args": {
            "list_id": list_id,
            "name": task_name,
        }
    },    
    {
        "name": "CLICKUP_GET_TASK",
        "args": {
            "task_id": task_id,
        }
    },
    {
        "name": "CLICKUP_UPDATE_TASK",
        "args": {
            "task_id": task_id,
            "name": updated_task_name,
            "assignees__add": [],
            "assignees__rem": [],
        }
    },
    {
        "name": "CLICKUP_DELETE_TASK",
        "args": {
            "task_id": task_id_2,
        }
    },
    {
        "name": "CLICKUP_GET_TASKS",
        "args": {
            "list_id": list_id,
        }
    },
    {
        "name": "CLICKUP_GET_LIST",
        "args": {
            "list_id": list_id,
        }
    },
    {
        "name": "CLICKUP_GET_LISTS",
        "args": {
            "folder_id": folder_id,
        }
    },
    {
        "name": "CLICKUP_ADD_TASK_TO_LIST",
        "args": {
            "list_id": list_id,
            "task_id": task_id,
        }
    },
    {
        "name": "CLICKUP_REMOVE_TASK_FROM_LIST",
        "args": {
            "list_id": list_id,
            "task_id": task_id,
        }
    },
    {
        "name": "CLICKUP_SPACES_GET_SPACE_DETAILS",
        "args": {
            "team_id": team_id,
        }
    },
    {
        "name": "CLICKUP_SPACES_GET_SPACE_DETAILS",
        "args": {
            "team_id": team_id,
        }
    },
]

# %%
short_results_1, full_results_1 = test_composio_clickup_tools(actions_with_args_1)
# Out:
# {'action': 'CLICKUP_AUTHORIZATION_VIEW_ACCOUNT_DETAILS', 'executed': {'executed': True}}
# {'action': 'CLICKUP_AUTHORIZATION_GET_WORK_SPACE_LIST', 'executed': {'executed': True}}
# {'action': 'CLICKUP_CREATE_TASK', 'executed': {'executed': True}}
# {'action': 'CLICKUP_GET_TASK', 'executed': {'executed': True}}
# {'action': 'CLICKUP_UPDATE_TASK', 'executed': {'executed': True}}
# {'action': 'CLICKUP_DELETE_TASK', 'executed': {'executed': True}}
# {'action': 'CLICKUP_GET_TASKS', 'executed': {'executed': True}}
# {'action': 'CLICKUP_GET_LIST', 'executed': {'executed': True}}
# {'action': 'CLICKUP_GET_LISTS', 'executed': {'executed': False}}
# {'action': 'CLICKUP_ADD_TASK_TO_LIST', 'executed': {'executed': False}}
# {'action': 'CLICKUP_REMOVE_TASK_FROM_LIST', 'executed': {'executed': False}}
# {'action': 'CLICKUP_SPACES_GET_SPACE_DETAILS', 'executed': {'executed': True}}
# {'action': 'CLICKUP_SPACES_GET_SPACE_DETAILS', 'executed': {'executed': True}}
# Total time taken: 0:00:42.464707

# %%
full_results_1
# Out:
# [{'action': 'CLICKUP_AUTHORIZATION_VIEW_ACCOUNT_DETAILS',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'user': {'id': 81918955,
#      'username': 'João Guilherme Silva Morossini',
#      'email': 'joaog.morossini@gmail.com',
#      'color': '#81b1ff',
#      'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg',
#      'initials': 'JM',
#      'week_start_day': 1,
#      'global_font_support': True,
#      'timezone': 'America/Sao_Paulo'}}}},
#  {'action': 'CLICKUP_AUTHORIZATION_GET_WORK_SPACE_LIST',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'teams': [{'id': '12927880',
#       'name': 'Cogmo Workspace',
#       'color': '#202020',
#       'avatar': 'https://attachments2.clickup.com/team_avatars/12927880_9xT.blob?Expires=1735603200&Key-Pair-Id=APKAIYJRUKB5RLQWHZWQ&Signature=IjQQWt2qYTYv5yXQn3jhIfm5i9-ETIQdodisZqlZDGzoY4qAE5qvv~0FHDxbzSqeN0Rd-osZw5sJIpIpYWO1SPzvm2u-gVJgy9RGaaB4KtnMyZw-wStnG67hevdPdOukxHFE~VLEEP2HoHSnYyWyjUrMFmA0f256ZsU8hhM4Lq8JuUfFJyi69HbCD2l~F8kCeLOadW4z0ofkTTMfVNjDrqezFkiL72Rlr3v~bmq3oCGKIaAMZFWyorq3ru5HDJvphqudIkrFpA56kIgESPIzzU3lkINk7CVHJ2xKRRnU4ruo4cjufxo5RAtL9RehP5gaP8r2A1BmgDlZ5uLTUiK0kg__',
#       'members': [{'user': {'id': 84141406,
#          'username': 'Ana Beatriz',
#          'email': 'ti@cogmo.com.br',
#          'color': '#455963',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/84141406_ZkZ.jpg',
#          'initials': 'AB',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722443789446',
#          'date_joined': '1722348822697',
#          'date_invited': '1722348667135'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 44309342,
#          'username': 'Hibrael Loures',
#          'email': 'ibraelmoura@gmail.com',
#          'color': None,
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/44309342_YHC.jpg',
#          'initials': 'HL',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1719956684066',
#          'date_joined': '1719500887900',
#          'date_invited': '1719500735732'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 82061927,
#          'username': 'Rafael Alves Magalhães',
#          'email': 'magalhaesrafael07@gmail.com',
#          'color': '',
#          'profilePicture': None,
#          'initials': 'RM',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722456836029',
#          'date_joined': '1715710208104',
#          'date_invited': '1715710148238'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 3115657,
#          'username': 'Filipe Werlang',
#          'email': 'filipewerlang.d@gmail.com',
#          'color': '#622aea',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/3115657_GPh.jpg',
#          'initials': 'FW',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1716570383387',
#          'date_joined': '1713903403635',
#          'date_invited': '1713903340285'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 72816031,
#          'username': 'Gabriel Silvestre',
#          'email': 'gabriel.h.silvestre11@gmail.com',
#          'color': '',
#          'profilePicture': None,
#          'initials': 'GS',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1711651350955',
#          'date_joined': '1706705323185',
#          'date_invited': '1706703387889'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81955248,
#          'username': 'Sara Lima dos Santos',
#          'email': 'zarahlimma@gmail.com',
#          'color': '#02579b',
#          'profilePicture': None,
#          'initials': 'SS',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1705520398448',
#          'date_joined': '1700762889153',
#          'date_invited': '1700762748501'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81942227,
#          'username': None,
#          'email': 'asdf@hbnjg.com',
#          'color': None,
#          'profilePicture': None,
#          'initials': 'A',
#          'role': 4,
#          'custom_role': None,
#          'last_active': None,
#          'date_joined': None,
#          'date_invited': '1697648867625'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81942111,
#          'username': 'Romulo Fernando',
#          'email': 'fssromulo@gmail.com',
#          'color': '#ff897f',
#          'profilePicture': None,
#          'initials': 'RF',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697657536419',
#          'date_joined': '1697639835143',
#          'date_invited': '1697639162077'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 32424453,
#          'username': 'Marcelo Marra',
#          'email': 'marcelo@devsquad.email',
#          'color': '#ffa12f',
#          'profilePicture': None,
#          'initials': 'MM',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697856401732',
#          'date_joined': '1697578574655',
#          'date_invited': '1697578470743'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81941856,
#          'username': 'Joseph Torres Kaltenecker',
#          'email': 'joseph.kaltenecker@gmail.com',
#          'color': '#d60800',
#          'profilePicture': None,
#          'initials': 'JK',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697684220484',
#          'date_joined': '1697584232755',
#          'date_invited': '1697569495566'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 42954980,
#          'username': 'Paulo Gontijo',
#          'email': 'paulo@devsquad.email',
#          'color': '#cddc39',
#          'profilePicture': None,
#          'initials': 'PG',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697629728042',
#          'date_joined': '1697564620641',
#          'date_invited': '1697549149854'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81934261,
#          'username': 'Davi Mello de Figueiredo',
#          'email': 'davi.figueiredo@devsquad.email',
#          'color': '#02579b',
#          'profilePicture': None,
#          'initials': 'DF',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697515706191',
#          'date_joined': '1696005734675',
#          'date_invited': '1695853301124'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 32443176,
#          'username': 'Wellington Mota',
#          'email': 'wellington@devsquad.email',
#          'color': '#006063',
#          'profilePicture': None,
#          'initials': 'WM',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697218599283',
#          'date_joined': '1696015880511',
#          'date_invited': '1695853300919'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 54949151,
#          'username': 'DAC CAPITAL',
#          'email': 'gerencial@daccapital.com.br',
#          'color': '#2ea52c',
#          'profilePicture': None,
#          'initials': 'DC',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1702326584933',
#          'date_joined': '1702326323812',
#          'date_invited': '1695150324637'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81930584,
#          'username': None,
#          'email': 'raquel.cardoso@daccapital.br',
#          'color': None,
#          'profilePicture': None,
#          'initials': 'R',
#          'role': 4,
#          'custom_role': None,
#          'last_active': None,
#          'date_joined': None,
#          'date_invited': '1695150306102'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 54951651,
#          'username': 'Legal',
#          'email': 'legal@daccapital.com.br',
#          'color': '#622aea',
#          'profilePicture': None,
#          'initials': 'L',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1695665069022',
#          'date_joined': '1695151113312',
#          'date_invited': '1694655863772'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81918955,
#          'username': 'João Guilherme Silva Morossini',
#          'email': 'joaog.morossini@gmail.com',
#          'color': '#81b1ff',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg',
#          'initials': 'JM',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722454159041',
#          'date_joined': '1693245712205',
#          'date_invited': '1693245455315'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 55040420,
#          'username': 'Gabriela Barreto Alberton',
#          'email': 'gabibalberton@gmail.com',
#          'color': '#f8306d',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/55040420_3Pe.jpg',
#          'initials': 'GA',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1695936684276',
#          'date_joined': '1671653244700',
#          'date_invited': '1671653134716'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 3195751,
#          'username': 'Nicolas Augusto França Melo',
#          'email': 'nicolasfmelo@gmail.com',
#          'color': '#ff4081',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/3195751_KsS.jpg',
#          'initials': 'NM',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1701520726948',
#          'date_joined': '1670092173360',
#          'date_invited': '1670092062140'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 54979221,
#          'username': 'Caio Ferreira da Costa Macedo',
#          'email': 'cmacedo2011@hotmail.com',
#          'color': '#ff4081',
#          'profilePicture': None,
#          'initials': 'CM',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722259039710',
#          'date_joined': '1667955977241',
#          'date_invited': '1667952178032'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 54969508,
#          'username': 'Jessé Dantas Macedo Santos de Jesus',
#          'email': 'jessedantasti@gmail.com',
#          'color': '#388d3c',
#          'profilePicture': None,
#          'initials': 'JJ',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1719953610878',
#          'date_joined': '1667507094940',
#          'date_invited': '1667506942142'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 54951654,
#          'username': 'RAQUEL AMARAL CARDOSO',
#          'email': 'raquel.cardoso@daccapital.com.br',
#          'color': '#622aea',
#          'profilePicture': None,
#          'initials': 'RC',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1675922064014',
#          'date_joined': '1667487082668',
#          'date_invited': '1667356810385'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 54939390,
#          'username': 'gisleine',
#          'email': 'gbalberton@gmail.com',
#          'color': None,
#          'profilePicture': None,
#          'initials': 'G',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1709398469540',
#          'date_joined': '1666206215365',
#          'date_invited': '1666206167107'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 49198435,
#          'username': 'Rafael Macedo Mendonça',
#          'email': 'rafael.macedo@perceptus.ai',
#          'color': '#5d4037',
#          'profilePicture': None,
#          'initials': 'RM',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722262592473',
#          'date_joined': '1664404432181',
#          'date_invited': '1664404270203'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 49198378,
#          'username': 'Ana Carolina Dos Santos',
#          'email': 'ana.carolina0509@gmail.com',
#          'color': '#795548',
#          'profilePicture': None,
#          'initials': 'AS',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1708656179438',
#          'date_joined': '1664410489464',
#          'date_invited': '1664401974533'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 49193170,
#          'username': 'Ricardo Terra',
#          'email': 'rterra88@gmail.com',
#          'color': '#07a092',
#          'profilePicture': None,
#          'initials': 'RT',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1720470355536',
#          'date_joined': '1664219470550',
#          'date_invited': '1664219444037'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 3027211,
#          'username': 'Denisson test',
#          'email': 'denissonfernades@gmail.com',
#          'color': '#afb42b',
#          'profilePicture': None,
#          'initials': 'DT',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1667362259881',
#          'date_joined': '1656636833254',
#          'date_invited': '1656633124280'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 48772077,
#          'username': 'Hélio Potelicki',
#          'email': 'helio@cogmo.com.br',
#          'color': '#2ea52c',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/48772077_rvb.jpg',
#          'initials': 'HP',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722453342757',
#          'date_joined': '1649266868990',
#          'date_invited': '1649266363940'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'email': 'gabriel@cogmo.com.br',
#          'color': '#7b68ee',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg',
#          'initials': 'GA',
#          'role': 1,
#          'custom_role': None,
#          'last_active': '1722453414299',
#          'date_joined': '1632348127957',
#          'date_invited': '1632348127957'}}]}]}}},
#  {'action': 'CLICKUP_CREATE_TASK',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'id': '86a4crxrq',
#     'custom_id': None,
#     'custom_item_id': 0,
#     'name': '-_-_NOVO TESTE COMPOSIO CLICKUP_-_-',
#     'text_content': '',
#     'description': '',
#     'status': {'id': 'p54804921_1gR1N0KG',
#      'status': 'backlog',
#      'color': '#9c09bc',
#      'orderindex': 0,
#      'type': 'open'},
#     'orderindex': '119424552.00000000000000000000000000000000',
#     'date_created': '1722458625815',
#     'date_updated': '1722458625815',
#     'date_closed': None,
#     'date_done': None,
#     'archived': False,
#     'creator': {'id': 81918955,
#      'username': 'João Guilherme Silva Morossini',
#      'color': '#81b1ff',
#      'email': 'joaog.morossini@gmail.com',
#      'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'},
#     'assignees': [],
#     'group_assignees': [],
#     'watchers': [{'id': 81918955,
#       'username': 'João Guilherme Silva Morossini',
#       'color': '#81b1ff',
#       'initials': 'JM',
#       'email': 'joaog.morossini@gmail.com',
#       'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'}],
#     'checklists': [],
#     'tags': [],
#     'parent': None,
#     'priority': None,
#     'due_date': None,
#     'start_date': None,
#     'points': None,
#     'time_estimate': None,
#     'time_spent': 0,
#     'custom_fields': [],
#     'dependencies': [],
#     'linked_tasks': [],
#     'locations': [],
#     'team_id': '12927880',
#     'url': 'https://app.clickup.com/t/86a4crxrq',
#     'sharing': {'public': False,
#      'public_share_expires_on': None,
#      'public_fields': ['assignees',
#       'priority',
#       'due_date',
#       'content',
#       'comments',
#       'attachments',
#       'customFields',
#       'subtasks',
#       'tags',
#       'checklists',
#       'coverimage'],
#      'token': None,
#      'seo_optimized': False},
#     'permission_level': 'create',
#     'list': {'id': '901304862476', 'name': 'composioTest', 'access': True},
#     'project': {'id': '90132407003',
#      'name': 'langflow',
#      'hidden': False,
#      'access': True},
#     'folder': {'id': '90132407003',
#      'name': 'langflow',
#      'hidden': False,
#      'access': True},
#     'space': {'id': '54804921'}}}},
#  {'action': 'CLICKUP_GET_TASK',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'id': '86a4crwd0',
#     'custom_id': None,
#     'custom_item_id': 0,
#     'name': 'UPDATE THIS TASK',
#     'text_content': '',
#     'description': '',
#     'status': {'id': 'p54804921_1gR1N0KG',
#      'status': 'backlog',
#      'color': '#9c09bc',
#      'orderindex': 0,
#      'type': 'open'},
#     'orderindex': '119424550.00000000000000000000000000000000',
#     'date_created': '1722458512999',
#     'date_updated': '1722458512999',
#     'date_closed': None,
#     'date_done': None,
#     'archived': False,
#     'creator': {'id': 81918955,
#      'username': 'João Guilherme Silva Morossini',
#      'color': '#81b1ff',
#      'email': 'joaog.morossini@gmail.com',
#      'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'},
#     'assignees': [],
#     'group_assignees': [],
#     'watchers': [{'id': 81918955,
#       'username': 'João Guilherme Silva Morossini',
#       'color': '#81b1ff',
#       'initials': 'JM',
#       'email': 'joaog.morossini@gmail.com',
#       'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'}],
#     'checklists': [],
#     'tags': [],
#     'parent': None,
#     'priority': None,
#     'due_date': None,
#     'start_date': None,
#     'points': None,
#     'time_estimate': None,
#     'time_spent': 0,
#     'custom_fields': [],
#     'dependencies': [],
#     'linked_tasks': [],
#     'locations': [],
#     'team_id': '12927880',
#     'url': 'https://app.clickup.com/t/86a4crwd0',
#     'sharing': {'public': False,
#      'public_share_expires_on': None,
#      'public_fields': ['assignees',
#       'priority',
#       'due_date',
#       'content',
#       'comments',
#       'attachments',
#       'customFields',
#       'subtasks',
#       'tags',
#       'checklists',
#       'coverimage'],
#      'token': None,
#      'seo_optimized': False},
#     'permission_level': 'create',
#     'list': {'id': '901304862476', 'name': 'composioTest', 'access': True},
#     'project': {'id': '90132407003',
#      'name': 'langflow',
#      'hidden': False,
#      'access': True},
#     'folder': {'id': '90132407003',
#      'name': 'langflow',
#      'hidden': False,
#      'access': True},
#     'space': {'id': '54804921'},
#     'attachments': []}}},
#  {'action': 'CLICKUP_UPDATE_TASK',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'id': '86a4crwd0',
#     'custom_id': None,
#     'custom_item_id': 0,
#     'name': 'NEW UPDATED TASK NAME',
#     'text_content': '',
#     'description': '',
#     'status': {'id': 'p54804921_1gR1N0KG',
#      'status': 'backlog',
#      'color': '#9c09bc',
#      'orderindex': 0,
#      'type': 'open'},
#     'orderindex': '119424550.00000000000000000000000000000000',
#     'date_created': '1722458512999',
#     'date_updated': '1722458632350',
#     'date_closed': None,
#     'date_done': None,
#     'archived': False,
#     'creator': {'id': 81918955,
#      'username': 'João Guilherme Silva Morossini',
#      'color': '#81b1ff',
#      'email': 'joaog.morossini@gmail.com',
#      'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'},
#     'assignees': [],
#     'group_assignees': [],
#     'watchers': [{'id': 81918955,
#       'username': 'João Guilherme Silva Morossini',
#       'color': '#81b1ff',
#       'initials': 'JM',
#       'email': 'joaog.morossini@gmail.com',
#       'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'}],
#     'checklists': [],
#     'tags': [],
#     'parent': None,
#     'priority': None,
#     'due_date': None,
#     'start_date': None,
#     'points': None,
#     'time_estimate': None,
#     'time_spent': 0,
#     'custom_fields': [],
#     'dependencies': [],
#     'linked_tasks': [],
#     'locations': [],
#     'team_id': '12927880',
#     'url': 'https://app.clickup.com/t/86a4crwd0',
#     'sharing': {'public': False,
#      'public_share_expires_on': None,
#      'public_fields': ['assignees',
#       'priority',
#       'due_date',
#       'content',
#       'comments',
#       'attachments',
#       'customFields',
#       'subtasks',
#       'tags',
#       'checklists',
#       'coverimage'],
#      'token': None,
#      'seo_optimized': False},
#     'permission_level': 'create',
#     'list': {'id': '901304862476', 'name': 'composioTest', 'access': True},
#     'project': {'id': '90132407003',
#      'name': 'langflow',
#      'hidden': False,
#      'access': True},
#     'folder': {'id': '90132407003',
#      'name': 'langflow',
#      'hidden': False,
#      'access': True},
#     'space': {'id': '54804921'},
#     'attachments': []}}},
#  {'action': 'CLICKUP_DELETE_TASK',
#   'results': {'execution_details': {'executed': True}, 'response_data': ''}},
#  {'action': 'CLICKUP_GET_TASKS',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'tasks': [{'id': '86a4crxrq',
#       'custom_id': None,
#       'custom_item_id': 0,
#       'name': '-_-_NOVO TESTE COMPOSIO CLICKUP_-_-',
#       'text_content': '',
#       'description': '',
#       'status': {'status': 'backlog',
#        'id': 'p54804921_1gR1N0KG',
#        'color': '#9c09bc',
#        'type': 'open',
#        'orderindex': 0},
#       'orderindex': '119424552.00000000000000000000000000000000',
#       'date_created': '1722458625815',
#       'date_updated': '1722458625815',
#       'date_closed': None,
#       'date_done': None,
#       'archived': False,
#       'creator': {'id': 81918955,
#        'username': 'João Guilherme Silva Morossini',
#        'color': '#81b1ff',
#        'email': 'joaog.morossini@gmail.com',
#        'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'},
#       'assignees': [],
#       'group_assignees': [],
#       'watchers': [{'id': 81918955,
#         'username': 'João Guilherme Silva Morossini',
#         'color': '#81b1ff',
#         'initials': 'JM',
#         'email': 'joaog.morossini@gmail.com',
#         'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'}],
#       'checklists': [],
#       'tags': [],
#       'parent': None,
#       'priority': None,
#       'due_date': None,
#       'start_date': None,
#       'points': None,
#       'time_estimate': None,
#       'custom_fields': [],
#       'dependencies': [],
#       'linked_tasks': [],
#       'locations': [],
#       'team_id': '12927880',
#       'url': 'https://app.clickup.com/t/86a4crxrq',
#       'sharing': {'public': False,
#        'public_share_expires_on': None,
#        'public_fields': ['assignees',
#         'priority',
#         'due_date',
#         'content',
#         'comments',
#         'attachments',
#         'customFields',
#         'subtasks',
#         'tags',
#         'checklists',
#         'coverimage'],
#        'token': None,
#        'seo_optimized': False},
#       'permission_level': 'create',
#       'list': {'id': '901304862476', 'name': 'composioTest', 'access': True},
#       'project': {'id': '90132407003',
#        'name': 'langflow',
#        'hidden': False,
#        'access': True},
#       'folder': {'id': '90132407003',
#        'name': 'langflow',
#        'hidden': False,
#        'access': True},
#       'space': {'id': '54804921'}},
#      {'id': '86a4crwd0',
#       'custom_id': None,
#       'custom_item_id': 0,
#       'name': 'NEW UPDATED TASK NAME',
#       'text_content': '',
#       'description': '',
#       'status': {'status': 'backlog',
#        'id': 'p54804921_1gR1N0KG',
#        'color': '#9c09bc',
#        'type': 'open',
#        'orderindex': 0},
#       'orderindex': '119424550.00000000000000000000000000000000',
#       'date_created': '1722458512999',
#       'date_updated': '1722458632350',
#       'date_closed': None,
#       'date_done': None,
#       'archived': False,
#       'creator': {'id': 81918955,
#        'username': 'João Guilherme Silva Morossini',
#        'color': '#81b1ff',
#        'email': 'joaog.morossini@gmail.com',
#        'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'},
#       'assignees': [],
#       'group_assignees': [],
#       'watchers': [{'id': 81918955,
#         'username': 'João Guilherme Silva Morossini',
#         'color': '#81b1ff',
#         'initials': 'JM',
#         'email': 'joaog.morossini@gmail.com',
#         'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'}],
#       'checklists': [],
#       'tags': [],
#       'parent': None,
#       'priority': None,
#       'due_date': None,
#       'start_date': None,
#       'points': None,
#       'time_estimate': None,
#       'custom_fields': [],
#       'dependencies': [],
#       'linked_tasks': [],
#       'locations': [],
#       'team_id': '12927880',
#       'url': 'https://app.clickup.com/t/86a4crwd0',
#       'sharing': {'public': False,
#        'public_share_expires_on': None,
#        'public_fields': ['assignees',
#         'priority',
#         'due_date',
#         'content',
#         'comments',
#         'attachments',
#         'customFields',
#         'subtasks',
#         'tags',
#         'checklists',
#         'coverimage'],
#        'token': None,
#        'seo_optimized': False},
#       'permission_level': 'create',
#       'list': {'id': '901304862476', 'name': 'composioTest', 'access': True},
#       'project': {'id': '90132407003',
#        'name': 'langflow',
#        'hidden': False,
#        'access': True},
#       'folder': {'id': '90132407003',
#        'name': 'langflow',
#        'hidden': False,
#        'access': True},
#       'space': {'id': '54804921'}}],
#     'last_page': True}}},
#  {'action': 'CLICKUP_GET_LIST',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'id': '901304862476',
#     'name': 'composioTest',
#     'deleted': False,
#     'orderindex': 2,
#     'content': '',
#     'priority': None,
#     'assignee': None,
#     'due_date': None,
#     'start_date': None,
#     'folder': {'id': '90132407003',
#      'name': 'langflow',
#      'hidden': False,
#      'access': True},
#     'space': {'id': '54804921', 'name': 'Projetos', 'access': True},
#     'inbound_address': 'a.t.901304862476.u-81918955.744af154-60a6-4717-81b4-d23a5d31a209@tasks.clickup.com',
#     'archived': False,
#     'override_statuses': False,
#     'statuses': [{'id': 'p54804921_1gR1N0KG',
#       'status': 'backlog',
#       'orderindex': 0,
#       'color': '#9c09bc',
#       'type': 'open',
#       'status_group': 'proj_54804921'},
#      {'id': 'p54804921_95z15BZN',
#       'status': 'todo',
#       'orderindex': 1,
#       'color': '#4466ff',
#       'type': 'custom',
#       'status_group': 'proj_54804921'},
#      {'id': 'p54804921_KslxIFrF',
#       'status': 'doing',
#       'orderindex': 2,
#       'color': '#e16b16',
#       'type': 'custom',
#       'status_group': 'proj_54804921'},
#      {'id': 'p54804921_oYhO88Lm',
#       'status': 'testing',
#       'orderindex': 3,
#       'color': '#d33d44',
#       'type': 'custom',
#       'status_group': 'proj_54804921'},
#      {'id': 'p54804921_sZXRFa49',
#       'status': 'brainstorming',
#       'orderindex': 4,
#       'color': '#1090e0',
#       'type': 'custom',
#       'status_group': 'proj_54804921'},
#      {'id': 'p54804921_yUsGlLJS',
#       'status': 'done',
#       'orderindex': 5,
#       'color': '#008844',
#       'type': 'closed',
#       'status_group': 'proj_54804921'}],
#     'permission_level': 'create'}}},
#  {'action': 'CLICKUP_GET_LISTS',
#   'results': {'execution_details': {'executed': False},
#    'response_data': {'error': '{"err":"Team not authorized","ECODE":"OAUTH_027"}',
#     'status_code': 401}}},
#  {'action': 'CLICKUP_ADD_TASK_TO_LIST',
#   'executed': {'executed': False},
#   'error': '3 validation errors for GetAccessTokenRequest\nclient_id\n  field required (type=value_error.missing)\nclient_secret\n  field required (type=value_error.missing)\ncode\n  field required (type=value_error.missing)'},
#  {'action': 'CLICKUP_REMOVE_TASK_FROM_LIST',
#   'results': {'execution_details': {'executed': False},
#    'response_data': {'error': '{"err":"Task home list cannot be altered","ECODE":"TASK_035"}',
#     'status_code': 400}}},
#  {'action': 'CLICKUP_SPACES_GET_SPACE_DETAILS',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'spaces': [{'id': '54804921',
#       'name': 'Projetos',
#       'color': '#1ABC9C',
#       'private': False,
#       'avatar': None,
#       'admin_can_manage': True,
#       'statuses': [{'id': 'p54804921_1gR1N0KG',
#         'status': 'backlog',
#         'type': 'open',
#         'orderindex': 0,
#         'color': '#9c09bc'},
#        {'id': 'p54804921_95z15BZN',
#         'status': 'todo',
#         'type': 'custom',
#         'orderindex': 1,
#         'color': '#4466ff'},
#        {'id': 'p54804921_KslxIFrF',
#         'status': 'doing',
#         'type': 'custom',
#         'orderindex': 2,
#         'color': '#e16b16'},
#        {'id': 'p54804921_oYhO88Lm',
#         'status': 'testing',
#         'type': 'custom',
#         'orderindex': 3,
#         'color': '#d33d44'},
#        {'id': 'p54804921_sZXRFa49',
#         'status': 'brainstorming',
#         'type': 'custom',
#         'orderindex': 4,
#         'color': '#1090e0'},
#        {'id': 'p54804921_yUsGlLJS',
#         'status': 'done',
#         'type': 'closed',
#         'orderindex': 5,
#         'color': '#008844'}],
#       'multiple_assignees': True,
#       'features': {'due_dates': {'enabled': True,
#         'start_date': True,
#         'remap_due_dates': True,
#         'remap_closed_due_date': False},
#        'sprints': {'enabled': False},
#        'time_tracking': {'enabled': True,
#         'harvest': False,
#         'rollup': False,
#         'default_to_billable': 2},
#        'points': {'enabled': False},
#        'custom_items': {'enabled': False},
#        'priorities': {'enabled': True,
#         'priorities': [{'color': '#f50000',
#           'id': '1',
#           'orderindex': '1',
#           'priority': 'urgent'},
#          {'color': '#f8ae00',
#           'id': '2',
#           'orderindex': '2',
#           'priority': 'high'},
#          {'color': '#6fddff',
#           'id': '3',
#           'orderindex': '3',
#           'priority': 'normal'},
#          {'color': '#d8d8d8',
#           'id': '4',
#           'orderindex': '4',
#           'priority': 'low'}]},
#        'tags': {'enabled': True},
#        'time_estimates': {'enabled': True,
#         'rollup': False,
#         'per_assignee': False},
#        'zoom': {'enabled': False},
#        'milestones': {'enabled': True},
#        'custom_fields': {'enabled': True},
#        'dependency_warning': {'enabled': True},
#        'status_pies': {'enabled': False},
#        'multiple_assignees': {'enabled': True},
#        'scheduler_enabled': False},
#       'archived': False},
#      {'id': '54964971',
#       'name': 'Onboard e infos',
#       'color': None,
#       'private': False,
#       'avatar': None,
#       'admin_can_manage': True,
#       'statuses': [{'id': 'p54964971_bnCuGGBv',
#         'status': 'to do',
#         'type': 'open',
#         'orderindex': 0,
#         'color': '#87909e'},
#        {'id': 'p54964971_Km4inFPG',
#         'status': 'complete',
#         'type': 'closed',
#         'orderindex': 1,
#         'color': '#008844'}],
#       'multiple_assignees': False,
#       'features': {'due_dates': {'enabled': True,
#         'start_date': True,
#         'remap_due_dates': False,
#         'remap_closed_due_date': False},
#        'sprints': {'enabled': False},
#        'points': {'enabled': False},
#        'custom_items': {'enabled': False},
#        'zoom': {'enabled': False},
#        'milestones': {'enabled': False},
#        'status_pies': {'enabled': False},
#        'time_tracking': {'default_to_billable': 2},
#        'scheduler_enabled': False},
#       'archived': False}]}}},
#  {'action': 'CLICKUP_SPACES_GET_SPACE_DETAILS',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'spaces': [{'id': '54804921',
#       'name': 'Projetos',
#       'color': '#1ABC9C',
#       'private': False,
#       'avatar': None,
#       'admin_can_manage': True,
#       'statuses': [{'id': 'p54804921_1gR1N0KG',
#         'status': 'backlog',
#         'type': 'open',
#         'orderindex': 0,
#         'color': '#9c09bc'},
#        {'id': 'p54804921_95z15BZN',
#         'status': 'todo',
#         'type': 'custom',
#         'orderindex': 1,
#         'color': '#4466ff'},
#        {'id': 'p54804921_KslxIFrF',
#         'status': 'doing',
#         'type': 'custom',
#         'orderindex': 2,
#         'color': '#e16b16'},
#        {'id': 'p54804921_oYhO88Lm',
#         'status': 'testing',
#         'type': 'custom',
#         'orderindex': 3,
#         'color': '#d33d44'},
#        {'id': 'p54804921_sZXRFa49',
#         'status': 'brainstorming',
#         'type': 'custom',
#         'orderindex': 4,
#         'color': '#1090e0'},
#        {'id': 'p54804921_yUsGlLJS',
#         'status': 'done',
#         'type': 'closed',
#         'orderindex': 5,
#         'color': '#008844'}],
#       'multiple_assignees': True,
#       'features': {'due_dates': {'enabled': True,
#         'start_date': True,
#         'remap_due_dates': True,
#         'remap_closed_due_date': False},
#        'sprints': {'enabled': False},
#        'time_tracking': {'enabled': True,
#         'harvest': False,
#         'rollup': False,
#         'default_to_billable': 2},
#        'points': {'enabled': False},
#        'custom_items': {'enabled': False},
#        'priorities': {'enabled': True,
#         'priorities': [{'color': '#f50000',
#           'id': '1',
#           'orderindex': '1',
#           'priority': 'urgent'},
#          {'color': '#f8ae00',
#           'id': '2',
#           'orderindex': '2',
#           'priority': 'high'},
#          {'color': '#6fddff',
#           'id': '3',
#           'orderindex': '3',
#           'priority': 'normal'},
#          {'color': '#d8d8d8',
#           'id': '4',
#           'orderindex': '4',
#           'priority': 'low'}]},
#        'tags': {'enabled': True},
#        'time_estimates': {'enabled': True,
#         'rollup': False,
#         'per_assignee': False},
#        'zoom': {'enabled': False},
#        'milestones': {'enabled': True},
#        'custom_fields': {'enabled': True},
#        'dependency_warning': {'enabled': True},
#        'status_pies': {'enabled': False},
#        'multiple_assignees': {'enabled': True},
#        'scheduler_enabled': False},
#       'archived': False},
#      {'id': '54964971',
#       'name': 'Onboard e infos',
#       'color': None,
#       'private': False,
#       'avatar': None,
#       'admin_can_manage': True,
#       'statuses': [{'id': 'p54964971_bnCuGGBv',
#         'status': 'to do',
#         'type': 'open',
#         'orderindex': 0,
#         'color': '#87909e'},
#        {'id': 'p54964971_Km4inFPG',
#         'status': 'complete',
#         'type': 'closed',
#         'orderindex': 1,
#         'color': '#008844'}],
#       'multiple_assignees': False,
#       'features': {'due_dates': {'enabled': True,
#         'start_date': True,
#         'remap_due_dates': False,
#         'remap_closed_due_date': False},
#        'sprints': {'enabled': False},
#        'points': {'enabled': False},
#        'custom_items': {'enabled': False},
#        'zoom': {'enabled': False},
#        'milestones': {'enabled': False},
#        'status_pies': {'enabled': False},
#        'time_tracking': {'default_to_billable': 2},
#        'scheduler_enabled': False},
#       'archived': False}]}}}]

# %% [markdown]
# # TEST 2
# Using INVALID task ids

# %%
team_id = 12927880
list_id = 901304862476
task_name = "-_-_COMPOSIO CLICKUP TEST 2_-_-"
task_id = "blablablalba"
task_id_2 = "fake_id"
folder_id = "54804921"
updated_task_name = "NEW UPDATED TASK NAME - TEST 2"

actions_with_args_2 = [
    {
        "name": "CLICKUP_AUTHORIZATION_VIEW_ACCOUNT_DETAILS",
        "args": {}
    },
    {
        "name": "CLICKUP_AUTHORIZATION_GET_WORK_SPACE_LIST",
        "args": {}
    },
    {
        "name": "CLICKUP_CREATE_TASK",
        "args": {
            "list_id": list_id,
            "name": task_name,
        }
    },    
    {
        "name": "CLICKUP_GET_TASK",
        "args": {
            "task_id": task_id,
        }
    },
    {
        "name": "CLICKUP_UPDATE_TASK",
        "args": {
            "task_id": task_id,
            "name": updated_task_name,
            "assignees__add": [],
            "assignees__rem": [],
        }
    },
    {
        "name": "CLICKUP_DELETE_TASK",
        "args": {
            "task_id": task_id_2,
        }
    },
    {
        "name": "CLICKUP_GET_TASKS",
        "args": {
            "list_id": list_id,
        }
    },
    {
        "name": "CLICKUP_GET_LIST",
        "args": {
            "list_id": list_id,
        }
    },
    {
        "name": "CLICKUP_GET_LISTS",
        "args": {
            "folder_id": folder_id,
        }
    },
    {
        "name": "CLICKUP_ADD_TASK_TO_LIST",
        "args": {
            "list_id": list_id,
            "task_id": task_id,
        }
    },
    {
        "name": "CLICKUP_REMOVE_TASK_FROM_LIST",
        "args": {
            "list_id": list_id,
            "task_id": task_id,
        }
    },
    {
        "name": "CLICKUP_SPACES_GET_SPACE_DETAILS",
        "args": {
            "team_id": team_id,
        }
    },
    {
        "name": "CLICKUP_SPACES_GET_SPACE_DETAILS",
        "args": {
            "team_id": team_id,
        }
    },
]

# %%
short_results_2, full_results_2 = test_composio_clickup_tools(actions_with_args_2)
# Out:
# {'action': 'CLICKUP_AUTHORIZATION_VIEW_ACCOUNT_DETAILS', 'executed': {'executed': True}}
# {'action': 'CLICKUP_AUTHORIZATION_GET_WORK_SPACE_LIST', 'executed': {'executed': True}}
# {'action': 'CLICKUP_CREATE_TASK', 'executed': {'executed': True}}
# {'action': 'CLICKUP_GET_TASK', 'executed': {'executed': False}}
# {'action': 'CLICKUP_UPDATE_TASK', 'executed': {'executed': False}}
# {'action': 'CLICKUP_DELETE_TASK', 'executed': {'executed': False}}
# {'action': 'CLICKUP_GET_TASKS', 'executed': {'executed': True}}
# {'action': 'CLICKUP_GET_LIST', 'executed': {'executed': True}}
# {'action': 'CLICKUP_GET_LISTS', 'executed': {'executed': False}}
# {'action': 'CLICKUP_ADD_TASK_TO_LIST', 'executed': {'executed': False}}
# {'action': 'CLICKUP_REMOVE_TASK_FROM_LIST', 'executed': {'executed': False}}
# {'action': 'CLICKUP_SPACES_GET_SPACE_DETAILS', 'executed': {'executed': True}}
# {'action': 'CLICKUP_SPACES_GET_SPACE_DETAILS', 'executed': {'executed': True}}
# Total time taken: 0:00:43.918521

# %%
full_results_2
# Out:
# [{'action': 'CLICKUP_AUTHORIZATION_VIEW_ACCOUNT_DETAILS',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'user': {'id': 81918955,
#      'username': 'João Guilherme Silva Morossini',
#      'email': 'joaog.morossini@gmail.com',
#      'color': '#81b1ff',
#      'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg',
#      'initials': 'JM',
#      'week_start_day': 1,
#      'global_font_support': True,
#      'timezone': 'America/Sao_Paulo'}}}},
#  {'action': 'CLICKUP_AUTHORIZATION_GET_WORK_SPACE_LIST',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'teams': [{'id': '12927880',
#       'name': 'Cogmo Workspace',
#       'color': '#202020',
#       'avatar': 'https://attachments2.clickup.com/team_avatars/12927880_9xT.blob?Expires=1735603200&Key-Pair-Id=APKAIYJRUKB5RLQWHZWQ&Signature=IjQQWt2qYTYv5yXQn3jhIfm5i9-ETIQdodisZqlZDGzoY4qAE5qvv~0FHDxbzSqeN0Rd-osZw5sJIpIpYWO1SPzvm2u-gVJgy9RGaaB4KtnMyZw-wStnG67hevdPdOukxHFE~VLEEP2HoHSnYyWyjUrMFmA0f256ZsU8hhM4Lq8JuUfFJyi69HbCD2l~F8kCeLOadW4z0ofkTTMfVNjDrqezFkiL72Rlr3v~bmq3oCGKIaAMZFWyorq3ru5HDJvphqudIkrFpA56kIgESPIzzU3lkINk7CVHJ2xKRRnU4ruo4cjufxo5RAtL9RehP5gaP8r2A1BmgDlZ5uLTUiK0kg__',
#       'members': [{'user': {'id': 84141406,
#          'username': 'Ana Beatriz',
#          'email': 'ti@cogmo.com.br',
#          'color': '#455963',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/84141406_ZkZ.jpg',
#          'initials': 'AB',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722443789446',
#          'date_joined': '1722348822697',
#          'date_invited': '1722348667135'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 44309342,
#          'username': 'Hibrael Loures',
#          'email': 'ibraelmoura@gmail.com',
#          'color': None,
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/44309342_YHC.jpg',
#          'initials': 'HL',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1719956684066',
#          'date_joined': '1719500887900',
#          'date_invited': '1719500735732'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 82061927,
#          'username': 'Rafael Alves Magalhães',
#          'email': 'magalhaesrafael07@gmail.com',
#          'color': '',
#          'profilePicture': None,
#          'initials': 'RM',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722456836029',
#          'date_joined': '1715710208104',
#          'date_invited': '1715710148238'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 3115657,
#          'username': 'Filipe Werlang',
#          'email': 'filipewerlang.d@gmail.com',
#          'color': '#622aea',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/3115657_GPh.jpg',
#          'initials': 'FW',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1716570383387',
#          'date_joined': '1713903403635',
#          'date_invited': '1713903340285'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 72816031,
#          'username': 'Gabriel Silvestre',
#          'email': 'gabriel.h.silvestre11@gmail.com',
#          'color': '',
#          'profilePicture': None,
#          'initials': 'GS',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1711651350955',
#          'date_joined': '1706705323185',
#          'date_invited': '1706703387889'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81955248,
#          'username': 'Sara Lima dos Santos',
#          'email': 'zarahlimma@gmail.com',
#          'color': '#02579b',
#          'profilePicture': None,
#          'initials': 'SS',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1705520398448',
#          'date_joined': '1700762889153',
#          'date_invited': '1700762748501'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81942227,
#          'username': None,
#          'email': 'asdf@hbnjg.com',
#          'color': None,
#          'profilePicture': None,
#          'initials': 'A',
#          'role': 4,
#          'custom_role': None,
#          'last_active': None,
#          'date_joined': None,
#          'date_invited': '1697648867625'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81942111,
#          'username': 'Romulo Fernando',
#          'email': 'fssromulo@gmail.com',
#          'color': '#ff897f',
#          'profilePicture': None,
#          'initials': 'RF',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697657536419',
#          'date_joined': '1697639835143',
#          'date_invited': '1697639162077'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 32424453,
#          'username': 'Marcelo Marra',
#          'email': 'marcelo@devsquad.email',
#          'color': '#ffa12f',
#          'profilePicture': None,
#          'initials': 'MM',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697856401732',
#          'date_joined': '1697578574655',
#          'date_invited': '1697578470743'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81941856,
#          'username': 'Joseph Torres Kaltenecker',
#          'email': 'joseph.kaltenecker@gmail.com',
#          'color': '#d60800',
#          'profilePicture': None,
#          'initials': 'JK',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697684220484',
#          'date_joined': '1697584232755',
#          'date_invited': '1697569495566'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 42954980,
#          'username': 'Paulo Gontijo',
#          'email': 'paulo@devsquad.email',
#          'color': '#cddc39',
#          'profilePicture': None,
#          'initials': 'PG',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697629728042',
#          'date_joined': '1697564620641',
#          'date_invited': '1697549149854'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81934261,
#          'username': 'Davi Mello de Figueiredo',
#          'email': 'davi.figueiredo@devsquad.email',
#          'color': '#02579b',
#          'profilePicture': None,
#          'initials': 'DF',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697515706191',
#          'date_joined': '1696005734675',
#          'date_invited': '1695853301124'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 32443176,
#          'username': 'Wellington Mota',
#          'email': 'wellington@devsquad.email',
#          'color': '#006063',
#          'profilePicture': None,
#          'initials': 'WM',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1697218599283',
#          'date_joined': '1696015880511',
#          'date_invited': '1695853300919'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 54949151,
#          'username': 'DAC CAPITAL',
#          'email': 'gerencial@daccapital.com.br',
#          'color': '#2ea52c',
#          'profilePicture': None,
#          'initials': 'DC',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1702326584933',
#          'date_joined': '1702326323812',
#          'date_invited': '1695150324637'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81930584,
#          'username': None,
#          'email': 'raquel.cardoso@daccapital.br',
#          'color': None,
#          'profilePicture': None,
#          'initials': 'R',
#          'role': 4,
#          'custom_role': None,
#          'last_active': None,
#          'date_joined': None,
#          'date_invited': '1695150306102'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 54951651,
#          'username': 'Legal',
#          'email': 'legal@daccapital.com.br',
#          'color': '#622aea',
#          'profilePicture': None,
#          'initials': 'L',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1695665069022',
#          'date_joined': '1695151113312',
#          'date_invited': '1694655863772'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 81918955,
#          'username': 'João Guilherme Silva Morossini',
#          'email': 'joaog.morossini@gmail.com',
#          'color': '#81b1ff',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg',
#          'initials': 'JM',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722454159041',
#          'date_joined': '1693245712205',
#          'date_invited': '1693245455315'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 55040420,
#          'username': 'Gabriela Barreto Alberton',
#          'email': 'gabibalberton@gmail.com',
#          'color': '#f8306d',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/55040420_3Pe.jpg',
#          'initials': 'GA',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1695936684276',
#          'date_joined': '1671653244700',
#          'date_invited': '1671653134716'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 3195751,
#          'username': 'Nicolas Augusto França Melo',
#          'email': 'nicolasfmelo@gmail.com',
#          'color': '#ff4081',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/3195751_KsS.jpg',
#          'initials': 'NM',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1701520726948',
#          'date_joined': '1670092173360',
#          'date_invited': '1670092062140'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 54979221,
#          'username': 'Caio Ferreira da Costa Macedo',
#          'email': 'cmacedo2011@hotmail.com',
#          'color': '#ff4081',
#          'profilePicture': None,
#          'initials': 'CM',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722259039710',
#          'date_joined': '1667955977241',
#          'date_invited': '1667952178032'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 54969508,
#          'username': 'Jessé Dantas Macedo Santos de Jesus',
#          'email': 'jessedantasti@gmail.com',
#          'color': '#388d3c',
#          'profilePicture': None,
#          'initials': 'JJ',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1719953610878',
#          'date_joined': '1667507094940',
#          'date_invited': '1667506942142'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 54951654,
#          'username': 'RAQUEL AMARAL CARDOSO',
#          'email': 'raquel.cardoso@daccapital.com.br',
#          'color': '#622aea',
#          'profilePicture': None,
#          'initials': 'RC',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1675922064014',
#          'date_joined': '1667487082668',
#          'date_invited': '1667356810385'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 49198435,
#          'username': 'Rafael Macedo Mendonça',
#          'email': 'rafael.macedo@perceptus.ai',
#          'color': '#5d4037',
#          'profilePicture': None,
#          'initials': 'RM',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722262592473',
#          'date_joined': '1664404432181',
#          'date_invited': '1664404270203'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 49198378,
#          'username': 'Ana Carolina Dos Santos',
#          'email': 'ana.carolina0509@gmail.com',
#          'color': '#795548',
#          'profilePicture': None,
#          'initials': 'AS',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1708656179438',
#          'date_joined': '1664410489464',
#          'date_invited': '1664401974533'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 49193170,
#          'username': 'Ricardo Terra',
#          'email': 'rterra88@gmail.com',
#          'color': '#07a092',
#          'profilePicture': None,
#          'initials': 'RT',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1720470355536',
#          'date_joined': '1664219470550',
#          'date_invited': '1664219444037'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 3027211,
#          'username': 'Denisson test',
#          'email': 'denissonfernades@gmail.com',
#          'color': '#afb42b',
#          'profilePicture': None,
#          'initials': 'DT',
#          'role': 4,
#          'custom_role': None,
#          'last_active': '1667362259881',
#          'date_joined': '1656636833254',
#          'date_invited': '1656633124280'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'},
#         'can_see_time_spent': True,
#         'can_see_time_estimated': True,
#         'can_see_points_estimated': True,
#         'can_edit_tags': False,
#         'can_create_views': False},
#        {'user': {'id': 48772077,
#          'username': 'Hélio Potelicki',
#          'email': 'helio@cogmo.com.br',
#          'color': '#2ea52c',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/48772077_rvb.jpg',
#          'initials': 'HP',
#          'role': 3,
#          'custom_role': None,
#          'last_active': '1722453342757',
#          'date_joined': '1649266868990',
#          'date_invited': '1649266363940'},
#         'invited_by': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'color': '#7b68ee',
#          'email': 'gabriel@cogmo.com.br',
#          'initials': 'GA',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg'}},
#        {'user': {'id': 18951490,
#          'username': 'Gabriel Alberton',
#          'email': 'gabriel@cogmo.com.br',
#          'color': '#7b68ee',
#          'profilePicture': 'https://attachments.clickup.com/profilePictures/18951490_W33.jpg',
#          'initials': 'GA',
#          'role': 1,
#          'custom_role': None,
#          'last_active': '1722453414299',
#          'date_joined': '1632348127957',
#          'date_invited': '1632348127957'}}]}]}}},
#  {'action': 'CLICKUP_CREATE_TASK',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'id': '86a4cry0v',
#     'custom_id': None,
#     'custom_item_id': 0,
#     'name': '-_-_COMPOSIO CLICKUP TEST 2_-_-',
#     'text_content': '',
#     'description': '',
#     'status': {'id': 'p54804921_1gR1N0KG',
#      'status': 'backlog',
#      'color': '#9c09bc',
#      'orderindex': 0,
#      'type': 'open'},
#     'orderindex': '119424553.00000000000000000000000000000000',
#     'date_created': '1722458667587',
#     'date_updated': '1722458667587',
#     'date_closed': None,
#     'date_done': None,
#     'archived': False,
#     'creator': {'id': 81918955,
#      'username': 'João Guilherme Silva Morossini',
#      'color': '#81b1ff',
#      'email': 'joaog.morossini@gmail.com',
#      'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'},
#     'assignees': [],
#     'group_assignees': [],
#     'watchers': [{'id': 81918955,
#       'username': 'João Guilherme Silva Morossini',
#       'color': '#81b1ff',
#       'initials': 'JM',
#       'email': 'joaog.morossini@gmail.com',
#       'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'}],
#     'checklists': [],
#     'tags': [],
#     'parent': None,
#     'priority': None,
#     'due_date': None,
#     'start_date': None,
#     'points': None,
#     'time_estimate': None,
#     'time_spent': 0,
#     'custom_fields': [],
#     'dependencies': [],
#     'linked_tasks': [],
#     'locations': [],
#     'team_id': '12927880',
#     'url': 'https://app.clickup.com/t/86a4cry0v',
#     'sharing': {'public': False,
#      'public_share_expires_on': None,
#      'public_fields': ['assignees',
#       'priority',
#       'due_date',
#       'content',
#       'comments',
#       'attachments',
#       'customFields',
#       'subtasks',
#       'tags',
#       'checklists',
#       'coverimage'],
#      'token': None,
#      'seo_optimized': False},
#     'permission_level': 'create',
#     'list': {'id': '901304862476', 'name': 'composioTest', 'access': True},
#     'project': {'id': '90132407003',
#      'name': 'langflow',
#      'hidden': False,
#      'access': True},
#     'folder': {'id': '90132407003',
#      'name': 'langflow',
#      'hidden': False,
#      'access': True},
#     'space': {'id': '54804921'}}}},
#  {'action': 'CLICKUP_GET_TASK',
#   'results': {'execution_details': {'executed': False},
#    'response_data': {'error': '{"err":"Team not authorized","ECODE":"OAUTH_027"}',
#     'status_code': 401}}},
#  {'action': 'CLICKUP_UPDATE_TASK',
#   'results': {'execution_details': {'executed': False},
#    'response_data': {'error': '{"err":"Team not authorized","ECODE":"OAUTH_027"}',
#     'status_code': 401}}},
#  {'action': 'CLICKUP_DELETE_TASK',
#   'results': {'execution_details': {'executed': False},
#    'response_data': {'error': '{"err":"Team not authorized","ECODE":"OAUTH_027"}',
#     'status_code': 401}}},
#  {'action': 'CLICKUP_GET_TASKS',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'tasks': [{'id': '86a4cry0v',
#       'custom_id': None,
#       'custom_item_id': 0,
#       'name': '-_-_COMPOSIO CLICKUP TEST 2_-_-',
#       'text_content': '',
#       'description': '',
#       'status': {'status': 'backlog',
#        'id': 'p54804921_1gR1N0KG',
#        'color': '#9c09bc',
#        'type': 'open',
#        'orderindex': 0},
#       'orderindex': '119424553.00000000000000000000000000000000',
#       'date_created': '1722458667587',
#       'date_updated': '1722458667587',
#       'date_closed': None,
#       'date_done': None,
#       'archived': False,
#       'creator': {'id': 81918955,
#        'username': 'João Guilherme Silva Morossini',
#        'color': '#81b1ff',
#        'email': 'joaog.morossini@gmail.com',
#        'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'},
#       'assignees': [],
#       'group_assignees': [],
#       'watchers': [{'id': 81918955,
#         'username': 'João Guilherme Silva Morossini',
#         'color': '#81b1ff',
#         'initials': 'JM',
#         'email': 'joaog.morossini@gmail.com',
#         'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'}],
#       'checklists': [],
#       'tags': [],
#       'parent': None,
#       'priority': None,
#       'due_date': None,
#       'start_date': None,
#       'points': None,
#       'time_estimate': None,
#       'custom_fields': [],
#       'dependencies': [],
#       'linked_tasks': [],
#       'locations': [],
#       'team_id': '12927880',
#       'url': 'https://app.clickup.com/t/86a4cry0v',
#       'sharing': {'public': False,
#        'public_share_expires_on': None,
#        'public_fields': ['assignees',
#         'priority',
#         'due_date',
#         'content',
#         'comments',
#         'attachments',
#         'customFields',
#         'subtasks',
#         'tags',
#         'checklists',
#         'coverimage'],
#        'token': None,
#        'seo_optimized': False},
#       'permission_level': 'create',
#       'list': {'id': '901304862476', 'name': 'composioTest', 'access': True},
#       'project': {'id': '90132407003',
#        'name': 'langflow',
#        'hidden': False,
#        'access': True},
#       'folder': {'id': '90132407003',
#        'name': 'langflow',
#        'hidden': False,
#        'access': True},
#       'space': {'id': '54804921'}},
#      {'id': '86a4crxrq',
#       'custom_id': None,
#       'custom_item_id': 0,
#       'name': '-_-_NOVO TESTE COMPOSIO CLICKUP_-_-',
#       'text_content': '',
#       'description': '',
#       'status': {'status': 'backlog',
#        'id': 'p54804921_1gR1N0KG',
#        'color': '#9c09bc',
#        'type': 'open',
#        'orderindex': 0},
#       'orderindex': '119424552.00000000000000000000000000000000',
#       'date_created': '1722458625815',
#       'date_updated': '1722458625815',
#       'date_closed': None,
#       'date_done': None,
#       'archived': False,
#       'creator': {'id': 81918955,
#        'username': 'João Guilherme Silva Morossini',
#        'color': '#81b1ff',
#        'email': 'joaog.morossini@gmail.com',
#        'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'},
#       'assignees': [],
#       'group_assignees': [],
#       'watchers': [{'id': 81918955,
#         'username': 'João Guilherme Silva Morossini',
#         'color': '#81b1ff',
#         'initials': 'JM',
#         'email': 'joaog.morossini@gmail.com',
#         'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'}],
#       'checklists': [],
#       'tags': [],
#       'parent': None,
#       'priority': None,
#       'due_date': None,
#       'start_date': None,
#       'points': None,
#       'time_estimate': None,
#       'custom_fields': [],
#       'dependencies': [],
#       'linked_tasks': [],
#       'locations': [],
#       'team_id': '12927880',
#       'url': 'https://app.clickup.com/t/86a4crxrq',
#       'sharing': {'public': False,
#        'public_share_expires_on': None,
#        'public_fields': ['assignees',
#         'priority',
#         'due_date',
#         'content',
#         'comments',
#         'attachments',
#         'customFields',
#         'subtasks',
#         'tags',
#         'checklists',
#         'coverimage'],
#        'token': None,
#        'seo_optimized': False},
#       'permission_level': 'create',
#       'list': {'id': '901304862476', 'name': 'composioTest', 'access': True},
#       'project': {'id': '90132407003',
#        'name': 'langflow',
#        'hidden': False,
#        'access': True},
#       'folder': {'id': '90132407003',
#        'name': 'langflow',
#        'hidden': False,
#        'access': True},
#       'space': {'id': '54804921'}},
#      {'id': '86a4crwd0',
#       'custom_id': None,
#       'custom_item_id': 0,
#       'name': 'NEW UPDATED TASK NAME',
#       'text_content': '',
#       'description': '',
#       'status': {'status': 'backlog',
#        'id': 'p54804921_1gR1N0KG',
#        'color': '#9c09bc',
#        'type': 'open',
#        'orderindex': 0},
#       'orderindex': '119424550.00000000000000000000000000000000',
#       'date_created': '1722458512999',
#       'date_updated': '1722458632350',
#       'date_closed': None,
#       'date_done': None,
#       'archived': False,
#       'creator': {'id': 81918955,
#        'username': 'João Guilherme Silva Morossini',
#        'color': '#81b1ff',
#        'email': 'joaog.morossini@gmail.com',
#        'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'},
#       'assignees': [],
#       'group_assignees': [],
#       'watchers': [{'id': 81918955,
#         'username': 'João Guilherme Silva Morossini',
#         'color': '#81b1ff',
#         'initials': 'JM',
#         'email': 'joaog.morossini@gmail.com',
#         'profilePicture': 'https://attachments.clickup.com/profilePictures/81918955_kcK.jpg'}],
#       'checklists': [],
#       'tags': [],
#       'parent': None,
#       'priority': None,
#       'due_date': None,
#       'start_date': None,
#       'points': None,
#       'time_estimate': None,
#       'custom_fields': [],
#       'dependencies': [],
#       'linked_tasks': [],
#       'locations': [],
#       'team_id': '12927880',
#       'url': 'https://app.clickup.com/t/86a4crwd0',
#       'sharing': {'public': False,
#        'public_share_expires_on': None,
#        'public_fields': ['assignees',
#         'priority',
#         'due_date',
#         'content',
#         'comments',
#         'attachments',
#         'customFields',
#         'subtasks',
#         'tags',
#         'checklists',
#         'coverimage'],
#        'token': None,
#        'seo_optimized': False},
#       'permission_level': 'create',
#       'list': {'id': '901304862476', 'name': 'composioTest', 'access': True},
#       'project': {'id': '90132407003',
#        'name': 'langflow',
#        'hidden': False,
#        'access': True},
#       'folder': {'id': '90132407003',
#        'name': 'langflow',
#        'hidden': False,
#        'access': True},
#       'space': {'id': '54804921'}}],
#     'last_page': True}}},
#  {'action': 'CLICKUP_GET_LIST',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'id': '901304862476',
#     'name': 'composioTest',
#     'deleted': False,
#     'orderindex': 2,
#     'content': '',
#     'priority': None,
#     'assignee': None,
#     'due_date': None,
#     'start_date': None,
#     'folder': {'id': '90132407003',
#      'name': 'langflow',
#      'hidden': False,
#      'access': True},
#     'space': {'id': '54804921', 'name': 'Projetos', 'access': True},
#     'inbound_address': 'a.t.901304862476.u-81918955.744af154-60a6-4717-81b4-d23a5d31a209@tasks.clickup.com',
#     'archived': False,
#     'override_statuses': False,
#     'statuses': [{'id': 'p54804921_1gR1N0KG',
#       'status': 'backlog',
#       'orderindex': 0,
#       'color': '#9c09bc',
#       'type': 'open',
#       'status_group': 'proj_54804921'},
#      {'id': 'p54804921_95z15BZN',
#       'status': 'todo',
#       'orderindex': 1,
#       'color': '#4466ff',
#       'type': 'custom',
#       'status_group': 'proj_54804921'},
#      {'id': 'p54804921_KslxIFrF',
#       'status': 'doing',
#       'orderindex': 2,
#       'color': '#e16b16',
#       'type': 'custom',
#       'status_group': 'proj_54804921'},
#      {'id': 'p54804921_oYhO88Lm',
#       'status': 'testing',
#       'orderindex': 3,
#       'color': '#d33d44',
#       'type': 'custom',
#       'status_group': 'proj_54804921'},
#      {'id': 'p54804921_sZXRFa49',
#       'status': 'brainstorming',
#       'orderindex': 4,
#       'color': '#1090e0',
#       'type': 'custom',
#       'status_group': 'proj_54804921'},
#      {'id': 'p54804921_yUsGlLJS',
#       'status': 'done',
#       'orderindex': 5,
#       'color': '#008844',
#       'type': 'closed',
#       'status_group': 'proj_54804921'}],
#     'permission_level': 'create'}}},
#  {'action': 'CLICKUP_GET_LISTS',
#   'results': {'execution_details': {'executed': False},
#    'response_data': {'error': '{"err":"Team not authorized","ECODE":"OAUTH_027"}',
#     'status_code': 401}}},
#  {'action': 'CLICKUP_ADD_TASK_TO_LIST',
#   'executed': {'executed': False},
#   'error': '3 validation errors for GetAccessTokenRequest\nclient_id\n  field required (type=value_error.missing)\nclient_secret\n  field required (type=value_error.missing)\ncode\n  field required (type=value_error.missing)'},
#  {'action': 'CLICKUP_REMOVE_TASK_FROM_LIST',
#   'results': {'execution_details': {'executed': False},
#    'response_data': {'error': '{"err":"Team not authorized","ECODE":"OAUTH_027"}',
#     'status_code': 401}}},
#  {'action': 'CLICKUP_SPACES_GET_SPACE_DETAILS',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'spaces': [{'id': '54804921',
#       'name': 'Projetos',
#       'color': '#1ABC9C',
#       'private': False,
#       'avatar': None,
#       'admin_can_manage': True,
#       'statuses': [{'id': 'p54804921_1gR1N0KG',
#         'status': 'backlog',
#         'type': 'open',
#         'orderindex': 0,
#         'color': '#9c09bc'},
#        {'id': 'p54804921_95z15BZN',
#         'status': 'todo',
#         'type': 'custom',
#         'orderindex': 1,
#         'color': '#4466ff'},
#        {'id': 'p54804921_KslxIFrF',
#         'status': 'doing',
#         'type': 'custom',
#         'orderindex': 2,
#         'color': '#e16b16'},
#        {'id': 'p54804921_oYhO88Lm',
#         'status': 'testing',
#         'type': 'custom',
#         'orderindex': 3,
#         'color': '#d33d44'},
#        {'id': 'p54804921_sZXRFa49',
#         'status': 'brainstorming',
#         'type': 'custom',
#         'orderindex': 4,
#         'color': '#1090e0'},
#        {'id': 'p54804921_yUsGlLJS',
#         'status': 'done',
#         'type': 'closed',
#         'orderindex': 5,
#         'color': '#008844'}],
#       'multiple_assignees': True,
#       'features': {'due_dates': {'enabled': True,
#         'start_date': True,
#         'remap_due_dates': True,
#         'remap_closed_due_date': False},
#        'sprints': {'enabled': False},
#        'time_tracking': {'enabled': True,
#         'harvest': False,
#         'rollup': False,
#         'default_to_billable': 2},
#        'points': {'enabled': False},
#        'custom_items': {'enabled': False},
#        'priorities': {'enabled': True,
#         'priorities': [{'color': '#f50000',
#           'id': '1',
#           'orderindex': '1',
#           'priority': 'urgent'},
#          {'color': '#f8ae00',
#           'id': '2',
#           'orderindex': '2',
#           'priority': 'high'},
#          {'color': '#6fddff',
#           'id': '3',
#           'orderindex': '3',
#           'priority': 'normal'},
#          {'color': '#d8d8d8',
#           'id': '4',
#           'orderindex': '4',
#           'priority': 'low'}]},
#        'tags': {'enabled': True},
#        'time_estimates': {'enabled': True,
#         'rollup': False,
#         'per_assignee': False},
#        'zoom': {'enabled': False},
#        'milestones': {'enabled': True},
#        'custom_fields': {'enabled': True},
#        'dependency_warning': {'enabled': True},
#        'status_pies': {'enabled': False},
#        'multiple_assignees': {'enabled': True},
#        'scheduler_enabled': False},
#       'archived': False},
#      {'id': '54964971',
#       'name': 'Onboard e infos',
#       'color': None,
#       'private': False,
#       'avatar': None,
#       'admin_can_manage': True,
#       'statuses': [{'id': 'p54964971_bnCuGGBv',
#         'status': 'to do',
#         'type': 'open',
#         'orderindex': 0,
#         'color': '#87909e'},
#        {'id': 'p54964971_Km4inFPG',
#         'status': 'complete',
#         'type': 'closed',
#         'orderindex': 1,
#         'color': '#008844'}],
#       'multiple_assignees': False,
#       'features': {'due_dates': {'enabled': True,
#         'start_date': True,
#         'remap_due_dates': False,
#         'remap_closed_due_date': False},
#        'sprints': {'enabled': False},
#        'points': {'enabled': False},
#        'custom_items': {'enabled': False},
#        'zoom': {'enabled': False},
#        'milestones': {'enabled': False},
#        'status_pies': {'enabled': False},
#        'time_tracking': {'default_to_billable': 2},
#        'scheduler_enabled': False},
#       'archived': False}]}}},
#  {'action': 'CLICKUP_SPACES_GET_SPACE_DETAILS',
#   'results': {'execution_details': {'executed': True},
#    'response_data': {'spaces': [{'id': '54804921',
#       'name': 'Projetos',
#       'color': '#1ABC9C',
#       'private': False,
#       'avatar': None,
#       'admin_can_manage': True,
#       'statuses': [{'id': 'p54804921_1gR1N0KG',
#         'status': 'backlog',
#         'type': 'open',
#         'orderindex': 0,
#         'color': '#9c09bc'},
#        {'id': 'p54804921_95z15BZN',
#         'status': 'todo',
#         'type': 'custom',
#         'orderindex': 1,
#         'color': '#4466ff'},
#        {'id': 'p54804921_KslxIFrF',
#         'status': 'doing',
#         'type': 'custom',
#         'orderindex': 2,
#         'color': '#e16b16'},
#        {'id': 'p54804921_oYhO88Lm',
#         'status': 'testing',
#         'type': 'custom',
#         'orderindex': 3,
#         'color': '#d33d44'},
#        {'id': 'p54804921_sZXRFa49',
#         'status': 'brainstorming',
#         'type': 'custom',
#         'orderindex': 4,
#         'color': '#1090e0'},
#        {'id': 'p54804921_yUsGlLJS',
#         'status': 'done',
#         'type': 'closed',
#         'orderindex': 5,
#         'color': '#008844'}],
#       'multiple_assignees': True,
#       'features': {'due_dates': {'enabled': True,
#         'start_date': True,
#         'remap_due_dates': True,
#         'remap_closed_due_date': False},
#        'sprints': {'enabled': False},
#        'time_tracking': {'enabled': True,
#         'harvest': False,
#         'rollup': False,
#         'default_to_billable': 2},
#        'points': {'enabled': False},
#        'custom_items': {'enabled': False},
#        'priorities': {'enabled': True,
#         'priorities': [{'color': '#f50000',
#           'id': '1',
#           'orderindex': '1',
#           'priority': 'urgent'},
#          {'color': '#f8ae00',
#           'id': '2',
#           'orderindex': '2',
#           'priority': 'high'},
#          {'color': '#6fddff',
#           'id': '3',
#           'orderindex': '3',
#           'priority': 'normal'},
#          {'color': '#d8d8d8',
#           'id': '4',
#           'orderindex': '4',
#           'priority': 'low'}]},
#        'tags': {'enabled': True},
#        'time_estimates': {'enabled': True,
#         'rollup': False,
#         'per_assignee': False},
#        'zoom': {'enabled': False},
#        'milestones': {'enabled': True},
#        'custom_fields': {'enabled': True},
#        'dependency_warning': {'enabled': True},
#        'status_pies': {'enabled': False},
#        'multiple_assignees': {'enabled': True},
#        'scheduler_enabled': False},
#       'archived': False},
#      {'id': '54964971',
#       'name': 'Onboard e infos',
#       'color': None,
#       'private': False,
#       'avatar': None,
#       'admin_can_manage': True,
#       'statuses': [{'id': 'p54964971_bnCuGGBv',
#         'status': 'to do',
#         'type': 'open',
#         'orderindex': 0,
#         'color': '#87909e'},
#        {'id': 'p54964971_Km4inFPG',
#         'status': 'complete',
#         'type': 'closed',
#         'orderindex': 1,
#         'color': '#008844'}],
#       'multiple_assignees': False,
#       'features': {'due_dates': {'enabled': True,
#         'start_date': True,
#         'remap_due_dates': False,
#         'remap_closed_due_date': False},
#        'sprints': {'enabled': False},
#        'points': {'enabled': False},
#        'custom_items': {'enabled': False},
#        'zoom': {'enabled': False},
#        'milestones': {'enabled': False},
#        'status_pies': {'enabled': False},
#        'time_tracking': {'default_to_billable': 2},
#        'scheduler_enabled': False},
#       'archived': False}]}}}]
